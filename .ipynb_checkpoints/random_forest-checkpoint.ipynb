# %%
import pandas as pd
import numpy as np
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split
from matplotlib import pyplot as plt

# %% [markdown]
# ## Splitting data into training set and testing set

# %%
dta = pd.read_csv('original_training_set/train.csv')

train, test = train_test_split(dta, test_size = 0.2)

train.to_csv('new_train_data.csv')
test.to_csv('new_test_data.csv')

# %% [markdown]
# ## Data of both training set and testing set

# %%
train_df1=pd.read_csv('new_train_data.csv')


train_df1.head()
# Out:
#    Unnamed: 0  customer_ID  shopping_pt  record_type  day   time state  \
# 0      113235     10023514            2            0    0  20:43    WA
# 1      566979     10131471            4            0    1  08:16    FL
# 2      153809     10034516            1            0    4  14:12    FL
# 3       90471     10019816            2            0    2  20:47    OR
# 4      363164     10082894            2            0    3  09:49    FL
#
#    location  group_size  homeowner  ...   C_previous duration_previous  A  B  \
# 0     12344           1          0  ...            3                 2  1  0
# 1     14271           1          1  ...            4                 9  1  0
# 2     12396           1          0  ...            2                 5  1  0
# 3     13218           1          0  ...            1                 3  1  1
# 4     10302           1          0  ...            1                 4  1  0
#
#    C  D  E  F  G  cost
# 0  1  1  0  2  2   679
# 1  4  3  1  1  3   633
# 2  1  3  0  2  3   622
# 3  1  1  0  2  3   684
# 4  1  1  0  2  3   641
#
# [5 rows x 26 columns]

# %%
test_df1=pd.read_csv('new_test_data.csv')
test_df1.head()
# Out:
#    Unnamed: 0  customer_ID  shopping_pt  record_type  day   time state  \
# 0      536193     10120560            2            0    2  13:42    NV
# 1      206825     10047691            6            0    2  13:13    FL
# 2      233525     10053910            1            0    1  14:59    MD
# 3      334825     10075745            2            0    3  17:06    ME
# 4      458662     10105308            7            0    4  15:04    PA
#
#    location  group_size  homeowner  ...   C_previous duration_previous  A  B  \
# 0     11435           2          1  ...            4                15  1  0
# 1     12790           1          1  ...            2                15  1  0
# 2     11419           1          1  ...            3                 4  1  0
# 3     10837           1          1  ...            2                 1  1  0
# 4     11699           1          1  ...            4                15  0  0
#
#    C  D  E  F  G  cost
# 0  4  3  0  1  3   599
# 1  2  3  1  2  3   595
# 2  3  3  0  2  3   630
# 3  3  3  1  1  1   612
# 4  1  2  0  0  1   586
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Pre-processing data

# %% [markdown]
# ### Removing the Unnamed column from the new training set

# %%
train_df1.shape
# Out:
# (532199, 26)

# %%
train_df1.drop(train_df1.columns[0],axis=1, inplace=True)

# %%
train_df1.shape
# Out:
# (532199, 25)

# %%
train_df1.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10023514            2            0    0  20:43    WA     12344
# 1     10131471            4            0    1  08:16    FL     14271
# 2     10034516            1            0    4  14:12    FL     12396
# 3     10019816            2            0    2  20:47    OR     13218
# 4     10082894            2            0    3  09:49    FL     10302
#
#    group_size  homeowner  car_age  ...  C_previous  duration_previous  A  B  \
# 0           1          0        1  ...           3                  2  1  0
# 1           1          1        3  ...           4                  9  1  0
# 2           1          0        3  ...           2                  5  1  0
# 3           1          0        9  ...           1                  3  1  1
# 4           1          0       11  ...           1                  4  1  0
#
#    C  D  E  F  G  cost
# 0  1  1  0  2  2   679
# 1  4  3  1  1  3   633
# 2  1  3  0  2  3   622
# 3  1  1  0  2  3   684
# 4  1  1  0  2  3   641
#
# [5 rows x 25 columns]

# %%
test_df1.shape
# Out:
# (133050, 26)

# %%
test_df1.drop(test_df1.columns[0],axis=1, inplace=True)

# %%
test_df1.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10120560            2            0    2  13:42    NV     11435
# 1     10047691            6            0    2  13:13    FL     12790
# 2     10053910            1            0    1  14:59    MD     11419
# 3     10075745            2            0    3  17:06    ME     10837
# 4     10105308            7            0    4  15:04    PA     11699
#
#    group_size  homeowner  car_age  ...  C_previous  duration_previous  A  B  \
# 0           2          1       13  ...           4                 15  1  0
# 1           1          1        1  ...           2                 15  1  0
# 2           1          1        2  ...           3                  4  1  0
# 3           1          1       11  ...           2                  1  1  0
# 4           1          1       15  ...           4                 15  0  0
#
#    C  D  E  F  G  cost
# 0  4  3  0  1  3   599
# 1  2  3  1  2  3   595
# 2  3  3  0  2  3   630
# 3  3  3  1  1  1   612
# 4  1  2  0  0  1   586
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Creating response vector and feature set

# %%
test_df1.isnull().values.sum()
# Out:
# 0

# %%
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
# df1 = pd.read_csv('new_train_data.csv')


# df1.head()

# %%
# df2=pd.read_csv('original_training_set/train.csv')
# df2.head()
